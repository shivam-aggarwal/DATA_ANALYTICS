# %% [markdown]
# # Feature Engineering - Regression

# %% [markdown]
# Imp Discussion https://towardsdatascience.com/why-how-and-when-to-apply-feature-selection-e9c69adfabf2

# %% [markdown]
# Import Dataset

# %%
from sklearn.datasets import load_boston
import pandas as pd

# %%
data = load_boston()

# %%
x = pd.DataFrame(data = data.data, columns=data.feature_names)

# %% [markdown]
# Basic Statistics

# %%
x.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
y = pd.DataFrame(data.target)

# %% [markdown]
# #### Feature Engineering

# %% [markdown]
# Linear model for testing the individual effect of each of many regressors.
#     This is a scoring function to be used in a feature selection procedure, not
#     a free standing feature selection procedure.
#     This is done in 2 steps:
#     1. The correlation between each regressor and the target is computed,
#        that is, ((X[:, i] - mean(X[:, i])) * (y - mean_y)) / (std(X[:, i]) *
#        std(y)).
#     2. It is converted to an F score then to a p-value.

# %%
from sklearn.feature_selection import f_regression

# %%
f_val = f_regression(x, y.iloc[:,0].values.ravel())

# %%
len(f_val)
# Out:
# 2

# %%
f = f_val[0]
f
# Out:
# array([ 89.48611476,  75.2576423 , 153.95488314,  15.97151242,
#        112.59148028, 471.84673988,  83.47745922,  33.57957033,
#         85.91427767, 141.76135658, 175.10554288,  63.05422911,
#        601.61787111])

# %%
p = f_val[1]

# %%
p
# Out:
# array([1.17398708e-19, 5.71358415e-17, 4.90025998e-31, 7.39062317e-05,
#        7.06504159e-24, 2.48722887e-74, 1.56998221e-18, 1.20661173e-08,
#        5.46593257e-19, 5.63773363e-29, 1.60950948e-34, 1.31811273e-14,
#        5.08110339e-88])

# %%
import matplotlib.pyplot as plt

# %%
features = list(x.columns)

# %%
len(features)
# Out:
# 13

# %%
fig, axs = plt.subplots(2, 7,figsize=(100,50),dpi=80)
for i in range(len(features)):
    dim = int("27" + str(i + 1))
    row = i//7 
    col = i - 7 * row
    _x = x.iloc[:,i].values.ravel()
    _y = y.iloc[:,0].values.ravel()
    axs[row,col].scatter(_x, _y)
    axs[row,col].set_title(features[i], fontsize=60)
    axs[row,col].set_xlabel('x',fontsize=50)
    axs[row,col].set_ylabel('y',fontsize=50)
